# %%
#%matplotlib nbagg
#%pylab
# %matplotlib notebook

# %%
import pyspark

sc = pyspark.sql.SparkSession.Builder().getOrCreate()

# %% [markdown]
# ## Levanto los archivos

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
points_recep = sc.read.json('datos/points-recep.jsonlines').rdd

# %% [markdown]
# ## Utils

# %%
def remove_no_receptions(l):
    return list(filter(lambda e: e > 0, l))

# %% [markdown]
# ### Cantidad de emisiones que tienen tanto señales recibidas como no para la antena 0 (aprox)

# %%
points_recep.filter(lambda x: len(x['recep_0']) > 0 and len(x['recep_0']) < 23).count()
# Out:
# 152

# %% [markdown]
# ### (1) Cantidad de emisiones validas (con datos)

# %%
em_cant = points_recep.filter(lambda x: len(x['recep_0']+x['recep_1']+x['recep_2']+x['recep_3'])).count()
p_cant = points_recep.filter(lambda x: len(x['recep_0']+x['recep_1']+x['recep_2']+x['recep_3'])).map(lambda x: x['Punto']).distinct().count()

print('cantidad de emisiones recibidas: {}'.format(em_cant))
print('cantidad de puntos con recepciones: {}'.format(p_cant))
# Out:
# cantidad de emisiones recibidas: 427
# cantidad de puntos con recepciones: 311

# %%
print('cantidad de puntos con una sola emision {}'.format(points_recep.filter(lambda x: len(x['recep_0']+x['recep_1']+x['recep_2']+x['recep_3'])).groupBy(lambda x: x['Punto']).filter(lambda x: len(list(x[1])) == 1).count()))
print('cantidad de puntos con dos emision {}'.format(points_recep.filter(lambda x: len(x['recep_0']+x['recep_1']+x['recep_2']+x['recep_3'])).groupBy(lambda x: x['Punto']).filter(lambda x: len(list(x[1])) == 2).count()))
print('cantidad de puntos con tres emision {}'.format(points_recep.filter(lambda x: len(x['recep_0']+x['recep_1']+x['recep_2']+x['recep_3'])).groupBy(lambda x: x['Punto']).filter(lambda x: len(list(x[1])) == 3).count()))
print('cantidad de puntos con mas de cuatro emisiones {}'.format(points_recep.filter(lambda x: len(x['recep_0']+x['recep_1']+x['recep_2']+x['recep_3'])).groupBy(lambda x: x['Punto']).filter(lambda x: len(list(x[1])) > 3).count()))
# Out:
# cantidad de puntos con una sola emision 202
# cantidad de puntos con dos emision 102
# cantidad de puntos con tres emision 7
# cantidad de puntos con mas de cuatro emisiones 0

# %% [markdown]
# ### (2) Cantidad de recepciones por antena

# %%
for i in range(4):
    cant = points_recep.map(lambda x: len(x['recep_{}'.format(i)])).sum()
    print('cant recepciones antena {}: {}'.format(i, cant))
# Out:
# cant recepciones antena 0: 4009
# cant recepciones antena 1: 2154
# cant recepciones antena 2: 1006
# cant recepciones antena 3: 3313

# %% [markdown]
# ### (3) Mean & Stdev de las recepciones de una misma emision

# %%
for i in range(4):
    recep_field = 'recep_{}'.format(i)
    recepciones = points_recep.filter(lambda x: len(x[recep_field]) > 0).map(lambda x: x[recep_field])
    mean = recepciones.map(lambda x: np.mean(x)).mean()
    stdev = recepciones.map(lambda x: np.std(x)).mean()
    coefficient_variation = recepciones.map(lambda x: np.std(x)/np.mean(x)).mean()
    
    print('mean power de antena {}: {}'.format(i, mean))
    print('mean stdev de antena {}: {}'.format(i, stdev))
    print('variation coef: {} \n'.format(coefficient_variation))
# Out:
# mean power de antena 0: 42.33003670935446
# mean stdev de antena 0: 4.136904114195276
# variation coef: 0.11049365382219475
#
# mean power de antena 1: 41.90019979203757
# mean stdev de antena 1: 5.172022513391275
# variation coef: 0.12537808151928978
#
# mean power de antena 2: 72.13334546570576
# mean stdev de antena 2: 15.24503294387743
# variation coef: 0.2260962824836419
#
# mean power de antena 3: 110.4690550520741
# mean stdev de antena 3: 21.723181346051938
# variation coef: 0.217089093503543

# %% [markdown]
# ### Ejemplos distribucion de potencia de emisiones

# %%
for i in range(4):
    recep_field = 'recep_{}'.format(i)
    recepciones = points_recep.filter(lambda x: len(x[recep_field]) > 0).map(lambda x: x[recep_field])
    l = recepciones.sample(False, fraction=0.05).collect()

    plt.figure()
    plt.title('Histograma antena {}'.format(i))
    for i in range(len(l)):
        plt.hist(l[i], rwidth=0.9)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### (4) Diferencia entre recepciones de un emisor en momentos distintos

# %% [markdown]
# ### Ejemplos de emisiones de puntos

# %%
for i in range(4):
    recep_field = 'recep_{}'.format(i)
    print(recep_field)
    points_with_many_emisions = points_recep.filter(lambda x: len(x[recep_field]) > 0).groupBy(lambda x: x['Punto']).filter(lambda x: len(x[1]) > 1)
    examples = points_with_many_emisions.map(lambda x: [recep[recep_field] for recep in list(x[1])]).takeSample(False,10)
    for e in examples: print(e)
    #print('potencia promedio de cada emision: {}'.format(points_with_many_emisions.map(lambda x: [np.mean(recep[recep_field]) for recep in list(x[1])]).take(10)))
    #print('promedio stdev del promedio de las potencias de cada emision: {} \n'.format(points_with_many_emisions.map(lambda x: np.std([np.mean(recep[recep_field]) for recep in list(x[1])])).mean()))
# Out:
# recep_0
# [[65, 50, 61, 68, 62, 75, 71, 74, 80, 77, 82, 66, 60, 56, 78, 80, 80, 62, 45, 50, 53, 72, 48, 72], [78, 77, 76, 77, 77, 71, 72, 67, 75, 70, 69, 63, 84, 83, 84, 84, 84, 84, 66, 64, 65, 65, 66, 53]]
# [[54, 55, 54, 55, 55, 53, 49, 46, 49, 43, 46, 55, 50, 52, 53, 53, 53, 57, 55, 53, 57, 63, 60, 59], [71, 67, 64, 66, 62, 63, 62, 62, 62, 62, 59, 60, 60, 64, 63]]
# [[30, 24, 34, 34, 30, 34, 24, 26, 26, 36, 36, 36, 33, 32, 34, 30, 37, 38, 34], [42, 46, 48, 45, 47, 42, 40, 46, 44, 40, 42, 41, 48, 42, 47, 46, 45, 47, 34, 24, 30, 28]]
# [[28], [48, 42, 37, 36, 35, 39, 45, 43, 44, 39, 39, 44, 42, 43, 44, 40, 44, 41, 39, 48, 48, 49, 50]]
# [[34, 37, 32, 36, 30, 40, 31, 41, 42, 40, 46, 43, 45, 43, 49, 48, 45, 43, 46, 51], [50, 53, 51, 54, 54, 51, 52, 49, 50, 46, 49, 49, 48, 36, 61, 64, 60, 61, 59, 57, 49, 46, 48, 43]]
# [[77, 74, 80, 79, 76, 72, 76, 78, 76, 78, 79, 80, 78, 81, 81, 80, 79, 77, 78, 84, 81], [83, 81, 81, 82, 81, 82, 82, 70, 76, 72, 72, 73, 72, 80, 80, 80, 80, 80, 79, 73, 73, 73, 72, 75]]
# [[33, 32, 31, 36, 33, 34], [40, 36, 34, 37, 42, 39, 36, 44, 43, 43, 42, 39, 33, 31, 19, 33, 34, 29, 33, 29, 26]]
# [[40, 36, 33, 34, 38, 27, 30, 31, 39, 40, 39, 32, 38, 38, 35, 33, 28, 34, 30, 32, 35], [46, 47, 51, 48, 50, 37, 44, 42, 45, 46, 45, 47, 46, 36, 44, 39, 39, 44, 42, 41, 47, 44, 40]]
# [[33, 32, 37, 22, 21, 40, 43, 40, 40, 45, 45, 27, 19, 32, 34, 48], [51, 52, 49, 52, 49, 46, 35, 39, 36, 35, 31, 33, 48, 24, 27]]
# [[43, 40, 41, 42, 39, 45, 47, 41, 32, 31, 28, 47, 42, 44, 49, 46, 43, 33, 41, 40, 39, 38, 39, 42], [51, 50, 50, 52, 50, 51, 47, 55, 48, 43, 48, 45, 45, 44, 51, 53, 53, 51, 52, 52, 50, 45, 45, 43]]
# recep_1
# [[34, 31, 35, 34, 30, 35, 38, 42, 46, 46, 45, 45, 44, 44, 45, 21], [42, 37, 37, 36, 38, 35, 35, 29, 42, 39, 37, 55, 58, 57, 58, 57, 57, 33, 40]]
# [[31, 28, 27, 29, 34], [39, 39, 39, 38, 43, 40, 36, 35, 24, 29, 53, 51, 53, 53, 52, 49]]
# [[41, 36, 41, 40, 39, 41, 42, 34, 38, 35, 43, 41, 43, 39, 35, 34, 32], [50, 56, 58, 54, 45, 56, 52, 43, 37, 41, 39, 45, 56, 53, 54, 54, 55, 52, 48, 48, 49, 48]]
# [[14, 28], [36, 27, 31]]
# recep_2
# [[171, 172, 167, 174, 155, 187, 189, 186, 190, 188, 159, 155, 158, 158, 164, 169, 94, 87, 156, 170, 151, 189], [186, 188, 197, 196, 195, 195, 196, 189, 186, 191, 189, 196, 200, 214, 216, 214, 208, 206, 218, 183, 190, 192, 189, 193]]
# [[42, 38, 45, 41, 31, 23, 12], [29, 14, 48, 19, 52, 53, 41, 50, 33, 64]]
# [[236, 240, 237, 235, 190, 181, 193, 188, 179, 182, 230, 230, 230, 234, 230, 225, 238, 199, 211, 220, 217, 215, 214, 209], [201, 189, 81]]
# [[204, 208, 209, 208, 210, 163, 164, 159, 174, 169, 208, 203, 208, 205, 204, 209, 161, 171, 180, 179, 184, 186, 227, 207], [239]]
# [[14], [42, 56, 57, 47, 35, 68, 40, 29, 13, 48, 48]]
# [[51], [70, 58, 66, 76, 64, 69, 54, 24, 83, 79, 67, 88, 86, 91, 84]]
# recep_3
# [[36], [36]]
# [[110, 47, 132, 138, 139, 135, 120], [110, 47, 132, 138, 139, 135, 120], [110, 47, 132, 138, 139, 135, 120]]
# [[151, 78, 82, 87, 86, 87, 66, 82, 69, 71, 83, 86, 151, 52, 74, 159, 174, 170, 174, 172], [151, 78, 82, 87, 86, 87, 66, 82, 69, 71, 83, 86, 151, 52, 74, 159, 174, 170, 174, 172]]
# [[139, 138, 138, 136, 141, 140, 135, 139, 140, 182, 180, 178, 180, 180, 150, 162, 163, 162, 166, 167, 162, 179, 179, 177], [139, 138, 138, 136, 141, 140, 135, 139, 140, 182, 180, 178, 180, 180, 150, 162, 163, 162, 166, 167, 162, 179, 179, 177]]
# [[165, 113, 110, 115, 120, 123, 131, 173, 134, 135, 156, 157, 157, 156, 182, 183, 179, 185, 192, 179, 180, 180, 174, 178], [165, 113, 110, 115, 120, 123, 131, 173, 134, 135, 156, 157, 157, 156, 182, 183, 179, 185, 192, 179, 180, 180, 174, 178]]
# [[226, 194, 240, 252, 253, 255, 254, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 253, 254, 255, 254, 209, 199], [226, 194, 240, 252, 253, 255, 254, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 253, 254, 255, 254, 209, 199]]
# [[108, 95, 102, 101, 97, 111, 133, 130, 135, 133, 136, 117, 118, 118, 143, 146, 146, 140, 146, 150, 143, 145, 147], [108, 95, 102, 101, 97, 111, 133, 130, 135, 133, 136, 117, 118, 118, 143, 146, 146, 140, 146, 150, 143, 145, 147]]
# [[54, 81], [54, 81], [54, 81]]
# [[194, 197, 195, 197, 198, 196, 192, 142, 145, 150, 146, 146, 148, 73, 137, 134, 132, 135, 132, 128, 13, 76, 59], [194, 197, 195, 197, 198, 196, 192, 142, 145, 150, 146, 146, 148, 73, 137, 134, 132, 135, 132, 128, 13, 76, 59]]
# [[72, 40, 33, 49, 30], [72, 40, 33, 49, 30]]

# %% [markdown]
# ### Las distintas emisiones de un mismo punto, tienen la misma distribucion?

# %%
from scipy import stats

  
def ks_test(grouped_data, antenna):
    recep_field = 'recep_{}'.format(antenna)
    emisiones = list(filter(lambda x: len(x[recep_field]), list(grouped_data[1])))
    return (grouped_data[0], stats.ks_2samp(emisiones[0][recep_field], emisiones[1][recep_field]))

for i in range(4):
    recep_field = 'recep_{}'.format(i)
    print(recep_field)
    
    points_with_many_emisions = points_recep.filter(lambda x: len(x[recep_field]) > 0).groupBy(lambda x: x['Punto']).filter(lambda x: len(x[1]) > 1)
    ks_test_by_point = points_with_many_emisions.map(lambda x: ks_test(x, i)).sortBy(lambda x: x[1].pvalue)
    print('same distribution amount {}'.format(ks_test_by_point.filter(lambda x: x[1].pvalue > 0.05).count()))
    print('total items with more than one emision for antenna {} \n'.format(points_with_many_emisions.count()))
# Out:
# recep_0
# same distribution amount 6
# total items with more than one emision for antenna 13
#
# recep_1
# same distribution amount 2
# total items with more than one emision for antenna 4
#
# recep_2
# same distribution amount 5
# total items with more than one emision for antenna 6
#
# recep_3
# same distribution amount 100
# total items with more than one emision for antenna 100

# %% [markdown]
# ### (5) Variación de la potencia de las señales en funcion de la cantidad de señales recibidas

# %%
def on_pick(event):
    artist = event.artist
    xmouse, ymouse = event.mouseevent.xdata, event.mouseevent.ydata
    x, y = artist.get_xdata(), artist.get_ydata()
    ind = event.ind
    raise Exception('oka')
    print('Artist picked:', event.artist)
    '''
    print '{} vertices picked'.format(len(ind))
    print 'Pick between vertices {} and {}'.format(min(ind), max(ind)+1)
    print 'x, y of mouse: {:.2f},{:.2f}'.format(xmouse, ymouse)
    print 'Data point:', x[ind[0]], y[ind[0]]
    print
    '''
    
def on_plot_hover(event):
    for curve in plot.get_lines():
        if curve.contains(event)[0]:
            print('over %s' % curve.get_gid())
'''
for i in range(4):
    recep_field = 'recep_{}'.format(i)
    p = points_recep.filter(lambda x: len(x[recep_field]) > 0).map(lambda x: {'n': len(x[recep_field]),'mean': float(np.mean(x[recep_field]))}).toDF().toPandas()
    p.plot.scatter(x='n', y='mean')
    plt.title('Puntos calibracion en antena {}'.format(i))
    fig, ax = plt.subplots()
    fig.canvas.callbacks.connect('pick_event', on_pick)
'''


i = 0
recep_field = 'recep_{}'.format(i)
p = points_recep.filter(lambda x: len(x[recep_field]) > 0).map(lambda x: {'n': len(x[recep_field]),'mean': float(np.mean(x[recep_field]))}).toDF().toPandas()
fig, ax = plt.subplots()
ax.scatter(p['n'], p['mean'])
fig.canvas.callbacks.connect('pick_event', on_pick)


fig.canvas.mpl_connect('motion_notify_event', on_plot_hover)
plt.show()
# Out:
# /Users/alew/py3/lib/python3.6/site-packages/pyspark/sql/session.py:366: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead
#   warnings.warn("Using RDD of dict to inferSchema is deprecated. "
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### (6) Mapa con colores

# %%
posicion_antenas = [(464063.427327232,6110287.773965900), (464063.427327232,6110287.773965900), (464063.427327232,6110287.773965900), (464063.427327232,6110287.773965900)]
coordenadas_UTM = sc.read.csv('datos/DistancesCoordenadasUTM.csv', header=True, inferSchema=True).rdd

# %%
def calculate_avg_power(grouped_row, antena):
    signals = list(map(lambda x: x['recep_{}'.format(antena)], list(grouped_row[1])))
    signals_pd = pd.DataFrame([s for emision in signals for s in emision ])
    n = len(signals_pd)
    if n > 0:
        mean = float(signals_pd.mean()[0])
        stdev = float(signals_pd.std()[0])
    else:
        mean = 0
        stdev = 0
    return {
        'Punto': grouped_row[0],
        'mean': mean,
        'stdev': stdev,
        'n': n,
        'x': list(grouped_row[1])[0]['x'],
        'y': list(grouped_row[1])[0]['y']
    }

# %%
x_0 = 462385.503783397
x_f = 465958.114906211
y_0 = 6109042.35153865
y_f = 6112715.80637111

global x_0
global y_0

def normalize_positions(row):
    row['x'] = row['x']-x_0
    row['y'] = row['y']-y_0
    return row

# %%
for antena in range(4):
    points_sig = points_recep.groupBy(lambda x:x['Punto']).map(lambda x: calculate_avg_power(x,antena)).map(normalize_positions)#.filter(lambda x: x['mean'] != 0)
    data = pd.DataFrame(points_sig.collect())
    ax = data.plot.scatter(x='x', y='y',c='mean',cmap='Oranges',s=data['stdev']+1)

    pos_antena = posicion_antenas[antena]
    ax.plot(pos_antena[0]-x_0, pos_antena[1]-y_0, "xb")
    plt.ylim(0,y_f-y_0)
    plt.xlim(0,x_f-x_0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
def calculate_amount_antennas_recep(grouped_row):
    signals = list(map(lambda x: [len(x['recep_{}'.format(i)])>0 for i in range(4)], list(grouped_row[1])))

    has_recep_by_antenna = np.array([False, False, False, False])
    for l in signals:
        has_recep_by_antenna = has_recep_by_antenna | np.array(l)

    return {
        'Punto': grouped_row[0],
        'cant': sum(has_recep_by_antenna),
        'x': list(grouped_row[1])[0]['x'],
        'y': list(grouped_row[1])[0]['y']
    }

# %%
points_sig = points_recep.groupBy(lambda x:x['Punto']).map(calculate_amount_antennas_recep).map(normalize_positions)
ax = pd.DataFrame(points_sig.collect()).plot.scatter(x='x', y='y',c='cant',cmap='Oranges')

for i in range(4):
    pos_antena = posicion_antenas[i]
    ax.plot(pos_antena[0]-x_0, pos_antena[1]-y_0, "xb")
    
plt.ylim(0,y_f-y_0)
plt.xlim(0,x_f-x_0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 3572.611122813949)

# %% [markdown]
# ### Cantidad de puntos por cantidad de antenas con recepcion

# %%
cant_recep = points_sig.groupBy(lambda x: x['cant']).map(lambda x: {'antennas': x[0],'cant_points': len(x[1])})

# %%
pd.DataFrame(cant_recep.collect()).plot.bar(x='antennas', y='cant_points')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### (7) Distancia promedio de las antenas a los puntos

# %%
import math
for antena in range(4):
    pos_antena = posicion_antenas[antena]
    mean_dist = coordenadas_UTM.map(lambda p: math.sqrt((pos_antena[0]-p['X'])**2+(pos_antena[1]-p['Y'])**2)).mean()
    print('mean distance to antenna {}: {}'.format(antena, mean_dist))

# %%
points_recep_df = sc.read.json('datos/points-recep.jsonlines').alias('asd')
bck_points_recep_df = sc.read.json('datos/bck-points-recep.jsonlines').alias('aux')
