# %%
# %matplotlib notebook

# %%
import pyspark
sc = pyspark.sql.SparkSession.Builder().getOrCreate()

# %%
import json
import numpy as np
import pandas as pd
import seaborn as sn

import matplotlib.pyplot as plt
from IPython.display import display, HTML
import math
import time
import random
from numpy.random import choice

import matplotlib.animation as animation
from datetime import datetime, timedelta
import pyspark.sql.functions as F

from utils.emissions_normalizer import EmissionsNormalizer
from utils.knn_predictor import KnnPredictor
from utils.smoother import Smoother
from utils.random_predictor import RandomPredictor

import utm

# %%
ANTENNAS_POSITION = [(464259.981343845,6110331.85100085),(463512.015195402,6111004.324434620),(464443.295130103,6111377.26171875),(464629.562194595,6111105.34734669)]
ANTENNAS_NAMES = ["RC1", "RC2", "D1", "D2"] 
X_0 = 462385.503783397
Y_0 = 6109042.35153865

for i in range(4):
    ANTENNAS_POSITION[i] = (ANTENNAS_POSITION[i][0]-X_0, ANTENNAS_POSITION[i][1]-Y_0)

# %%
FEMALES = [11, 15, 17, 20, 24, 26, 28, 30, 33, 34]
MALES = [10, 14, 16, 21, 22, 23, 25, 27, 29, 31, 32]

# %% [markdown]
# ## Entreno el modelo que vamos a usar para predecir

# %%
points_recep = sc.read.json('datos/train-test-by-emission.jsonlines/').rdd

# %%
normalizer = EmissionsNormalizer()
data = normalizer.normalize(points_recep)
regre_data, regre_target = normalizer.get_regression_dataframes(data)

# %%
predictor = KnnPredictor()
predictor.fit(regre_data, regre_target)

# %%
random_predictor = RandomPredictor()
random_predictor.fit(regre_data, regre_target)

# %%
validation_track = sc.read.csv('datos/validation_birds_tracks.csv', header=True)

# %%
def add_utm_coordinates(row):
    row_dict = row.asDict()
    x, y,_,_ = utm.from_latlon(float(row['Latitud']), float(row['Longitud']))
    row_dict['x'] = x
    row_dict['y'] = y
    return row_dict

def add_timestamp(row):
    row['timestamp'] = '{} {}'.format(
        datetime.strptime(row['Fecha'], '%m/%d/%Y').strftime('%Y-%m-%d'),
        row['Hora']
    )
    return row

# %%
validation_track = validation_track.rdd.map(add_utm_coordinates)

# %%
validation_track = validation_track.map(add_timestamp)

# %%
validation_track.take(1)
# Out:
# [{'ID': '30',
#   'Fecha': '1/19/2018',
#   'Hora': '10:34:00',
#   'Latitud': '-35.14944',
#   'Longitud': '-57.39189',
#   'Tipo': None,
#   'x': 464304.4317412587,
#   'y': 6110314.122618829,
#   'timestamp': '2018-01-19 10:34:00'}]

# %%
validations_list = validation_track.collect()

# %%
birds_recep = sc.read.json('datos/all-birds-data.jsonlines/').rdd

# %%
MAX_TIME_DIFF_SEC = 30
def add_validation(recep, validations_list):
    recep_timestamp = datetime.strptime(recep['timestamp'], '%Y-%m-%d %H:%M:%S')
    recep_tag_id = recep['tag_id']
    for val in validations_list:
        val_tag_id = int(val['ID'])
        if val_tag_id == recep_tag_id:
            val_timestamp = datetime.strptime(val['timestamp'], '%Y-%m-%d %H:%M:%S')
            time_diff = (recep_timestamp-val_timestamp).total_seconds()
            if abs(time_diff) <= MAX_TIME_DIFF_SEC:
                recep_dict = recep.asDict()
                recep_dict['time_diff'] = time_diff
                recep_dict['x'] = val['x']
                recep_dict['y'] = val['y']
                return recep_dict
    return None

# %%
birds_recep_with_val = birds_recep.map(lambda x: add_validation(x, validations_list)).filter(lambda x: x is not None)

# %%
birds_data = pd.DataFrame(birds_recep_with_val.collect())

# %%
birds_data['x'] = birds_data['x']-X_0
birds_data['y'] = birds_data['y']-Y_0
birds_data['time_diff_abs'] = abs(birds_data['time_diff'])

# %%
def get_min_time_diff(data):
    min_diff = 1000
    for index,row in data.iterrows():
        time_diff = row['time_diff_abs']
        if time_diff < min_diff:
            min_diff = time_diff
            best_row = row
    return best_row

# %%
birds_data = birds_data.groupby(['tag_id', 'x', 'y']).apply(get_min_time_diff).reset_index(drop=True)

# %%
predictions = predictor.predict(birds_data[['recep_0', 'recep_1', 'recep_2', 'recep_3']])

# %%
birds_data['predicted_x'] = predictions[:,0]
birds_data['predicted_y'] = predictions[:,1]

# %%
def get_abs_error(row, suffix=''):
    return math.sqrt((row['x']-row['predicted_x{}'.format(suffix)])**2 + (row['y']-row['predicted_y{}'.format(suffix)])**2)

# %%
birds_data['abs_error'] = birds_data.apply(get_abs_error, axis=1)

# %%
len(birds_data)
# Out:
# 16

# %%
birds_data.sort_values('time_diff_abs', ascending=True).head(n=50)
# Out:
#     recep_0  recep_1  recep_2  recep_3  tag_id  time_diff  \
# 4         0        0       34        0      21        0.0
# 10        0       47        0        0      32        0.0
# 12       31        0        0       88      32        0.0
# 3         0       46        0        0      21       -1.0
# 8         0       87        0        0      31        1.0
# 14        0       58        0        0      33       -1.0
# 0         0        0       86        0      17       -2.0
# 1         0       55        0        0      20        2.0
# 2         0        0      125        0      20        2.0
# 5        43        0        0        0      24       -2.0
# 6         0        0      161        0      27        2.0
# 15       28        0        0        0      33       -8.0
# 9         0       32        0        0      32       -9.0
# 7         0       71        0        0      30      -27.0
# 11        0       19        0        0      32       28.0
# 13        0       35        0        0      33       29.0
#
#               timestamp            x            y  time_diff_abs  predicted_x  \
# 4   2018-01-21 04:57:07  2242.602626  2358.764582            0.0  1830.391759
# 10  2018-01-19 11:28:00  2097.198918  1570.796323            0.0  1896.741952
# 12  2018-01-21 05:03:07  2395.186978  2242.912116            0.0  2501.365834
# 3   2018-01-19 11:27:59  2095.381480  1569.680188            1.0  2127.955860
# 8   2018-01-19 10:34:01  1918.927958  1271.771080            1.0  1994.152324
# 14  2018-01-19 11:27:59  2097.198918  1570.796323            1.0  1986.346772
# 0   2018-01-21 04:50:17  2154.785181  2451.578715            2.0  1742.565456
# 1   2018-01-19 11:28:02  2095.381480  1569.680188            2.0  1979.622716
# 2   2018-01-21 04:57:09  2242.602626  2358.764582            2.0  1725.037577
# 5   2018-01-21 05:13:23  2572.307280  2141.569133            2.0  1160.032611
# 6   2018-01-21 04:49:37  2150.217270  2454.887892            2.0  1997.860435
# 15  2018-01-21 05:02:59  2395.186978  2242.912116            8.0  1537.934009
# 9   2018-01-19 11:12:51  1854.529929  1664.108628            9.0  1888.119054
# 7   2018-01-19 10:33:33  1918.927958  1271.771080           27.0  1934.565828
# 11  2018-01-28 11:14:28  2163.464161  1629.833458           28.0  2349.162022
# 13  2018-01-19 11:13:29  1854.529929  1664.108628           29.0  2272.378907
#
#     predicted_y    abs_error
# 4   1571.521578   888.633415
# 10  1308.144824   330.407029
# 12  1808.472383   447.226823
# 3   1658.594341    94.693278
# 8   1349.697652   108.310922
# 14  1198.996168   387.973651
# 0   2202.175821   481.795501
# 1   1171.553595   414.614128
# 2   2051.563528   601.868813
# 5   2099.089602  1412.913391
# 6   2351.173469   184.307588
# 15  1861.172960   938.406861
# 9    975.893869   689.033950
# 7   1284.318848    20.049675
# 11  1315.274766   365.281899
# 13  1536.012428   437.042795

# %%
print('mean absolute error: {}'.format(birds_data['abs_error'].mean()))
print('median absolute error: {}'.format(birds_data['abs_error'].median()))
# Out:
# mean absolute error: 487.65998244690326
# median absolute error: 425.8284615121814

# %% [markdown]
# ### Pruebo con las smooth predictions

# %%
validation_days = set([e['timestamp'].split()[0] for e in validations_list])

# %%
validation_birds = set([int(e['ID']) for e in validations_list])

# %%
(
    birds_recep
    .filter(lambda x: x['timestamp'].split()[0] in validation_days and x['tag_id'] in validation_birds)
    .sortBy(lambda x: x['timestamp'])
    .toDF()
    .write.parquet('tmp/checkpoint-validation-predictors.parquet')
)

# %%
birds_recep_pd = pd.read_parquet('tmp/checkpoint-validation-predictors.parquet')

# %%
all_predictions = predictor.predict(birds_recep_pd[['recep_0', 'recep_1', 'recep_2', 'recep_3']])
all_predictions = pd.concat([pd.DataFrame(all_predictions), birds_recep_pd], axis=1).values

# %%
smoother = Smoother(step_size=0)
smooth_predictions = smoother.smooth_predictions(all_predictions)

# %%
smooth_predictions_pd = pd.DataFrame(smooth_predictions, columns=['predicted_x', 'predicted_y'] + birds_recep_pd.columns.values.tolist())

# %%
smooth_predictions_validation = (
    pd.merge(
        birds_data, 
        smooth_predictions_pd, on=['timestamp', 'tag_id'], 
        how='left', 
        suffixes=['', '_smooth']
    )
)

# %%
smooth_predictions_validation = smooth_predictions_validation[
    smooth_predictions_validation['predicted_x_smooth'].notna()
]

# %%
smooth_predictions_validation['abs_error'] = (
    smooth_predictions_validation
    .apply(lambda x: get_abs_error(x, suffix='_smooth'), axis=1)
)

# %%
smooth_predictions_validation.sort_values('time_diff_abs', ascending=True).head(n=50)
# Out:
#     recep_0  recep_1  recep_2  recep_3 tag_id  time_diff            timestamp  \
# 14       31        0        0       88     32        0.0  2018-01-21 05:03:07
# 12        0       47        0        0     32        0.0  2018-01-19 11:28:00
# 6         0        0       34        0     21        0.0  2018-01-21 04:57:07
# 10        0       87        0        0     31        1.0  2018-01-19 10:34:01
# 16        0       58        0        0     33       -1.0  2018-01-19 11:27:59
# 5         0       46        0        0     21       -1.0  2018-01-19 11:27:59
# 0         0        0       86        0     17       -2.0  2018-01-21 04:50:17
# 8         0        0      161        0     27        2.0  2018-01-21 04:49:37
# 3         0        0      125        0     20        2.0  2018-01-21 04:57:09
# 2         0       55        0        0     20        2.0  2018-01-19 11:28:02
# 7        43        0        0        0     24       -2.0  2018-01-21 05:13:23
# 17       28        0        0        0     33       -8.0  2018-01-21 05:02:59
# 11        0       32        0        0     32       -9.0  2018-01-19 11:12:51
# 9         0       71        0        0     30      -27.0  2018-01-19 10:33:33
# 13        0       19        0        0     32       28.0  2018-01-28 11:14:28
# 15        0       35        0        0     33       29.0  2018-01-19 11:13:29
# 1         0       33        0        0     20      -34.0  2018-01-19 11:41:26
# 4         0       57        0        0     21      -51.0  2018-01-19 11:41:09
#
#               x            y  predicted_x  predicted_y    abs_error  \
# 14  2395.186978  2242.912116  2501.365834  1808.472383   433.270276
# 12  2097.198918  1570.796323  1896.741952  1308.144824   318.675685
# 6   2242.602626  2358.764582  1830.391759  1571.521578   449.967328
# 10  1918.927958  1271.771080  1994.152324  1349.697652   153.721951
# 16  2097.198918  1570.796323  1986.346772  1198.996168   416.195770
# 5   2095.381480  1569.680188  2127.955860  1658.594341   433.127903
# 0   2154.785181  2451.578715  1742.565456  2202.175821   654.454492
# 8   2150.217270  2454.887892  1997.860435  2351.173469   279.295161
# 3   2242.602626  2358.764582  1725.037577  2051.563528   601.868813
# 2   2095.381480  1569.680188  1979.622716  1171.553595   411.997285
# 7   2572.307280  2141.569133  1160.032611  2099.089602  1256.723067
# 17  2395.186978  2242.912116  1537.934009  1861.172960   932.789372
# 11  1854.529929  1664.108628  1888.119054   975.893869   337.497709
# 9   1918.927958  1271.771080  1934.565828  1284.318848    20.049675
# 13  2163.464161  1629.833458  2349.162022  1315.274766   346.041453
# 15  1854.529929  1664.108628  2272.378907  1536.012428   562.777489
# 1   1914.386752  1268.426151  1771.091686  1091.746160   227.484714
# 4   1914.386752  1268.426151  1910.776962  1246.583630    22.138796
#
#     time_diff_abs predicted_x_smooth predicted_y_smooth recep_0_smooth  \
# 14            0.0             2582.8            1852.37           None
# 12            0.0            1989.38            1270.92           None
# 6             0.0            1864.84             2114.3           None
# 10            1.0             2029.5            1378.56           None
# 16            1.0            1979.62            1171.55           None
# 5             1.0            2161.26            1141.59           None
# 0             2.0             1760.4             1929.3           None
# 8             2.0            1961.11            2249.35           None
# 3             2.0            1725.04            2051.56           None
# 2             2.0            1989.38            1171.55           None
# 7             2.0            1365.09            1792.33           None
# 17            8.0            1530.93            1891.96           None
# 11            9.0            1983.54            1352.24           None
# 9            27.0            1934.57            1284.32           None
# 13           28.0            2173.58            1283.94           None
# 15           29.0            2064.97            1142.16           None
# 1            34.0            1771.09            1091.75           None
# 4            51.0            1910.78            1246.58           None
#
#    recep_1_smooth recep_2_smooth recep_3_smooth
# 14           None           None           None
# 12           None           None           None
# 6            None           None           None
# 10           None           None           None
# 16           None           None           None
# 5            None           None           None
# 0            None           None           None
# 8            None           None           None
# 3            None           None           None
# 2            None           None           None
# 7            None           None           None
# 17           None           None           None
# 11           None           None           None
# 9            None           None           None
# 13           None           None           None
# 15           None           None           None
# 1            None           None           None
# 4            None           None           None

# %%
print('mean absolute error: {}'.format(smooth_predictions_validation['abs_error'].mean()))
print('median absolute error: {}'.format(smooth_predictions_validation['abs_error'].median()))
# Out:
# mean absolute error: 436.5598298413461
# median absolute error: 414.09652721201667
